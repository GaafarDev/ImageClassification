# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50, VGG16, MobileNetV2
from tensorflow.keras.models import Sequential, Model
from sklearn.metrics import confusion_matrix

# Helper libraries
import numpy as np
import seaborn as sns
import matplotlib
matplotlib.use('Agg')  # Use 'TkAgg' if you want to display plots in a separate window
import matplotlib.pyplot as plt
import PIL
from sklearn.model_selection import KFold
from tqdm import tqdm
import os

# New imports for model visualization
import graphviz
import pydot
from tensorflow.keras.utils import plot_model
from IPython.display import display, Image

# %%
# Load the dataset
train_dir = r"D:\University Materials\SM 5\Adcanved AI\seg_train\seg_train"
test_dir = r"D:\University Materials\SM 5\Adcanved AI\seg_test\seg_test"
class_names = ["buildings", "forest", "glacier", "mountain", "sea", "street"]

# %%
# Define image size and batch size
img_height = 150
img_width = 150
batch_size = 32

# %%
# Create data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="sparse",
    subset="training"
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="sparse",
    subset="validation"
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="sparse"
)
# Out:
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.

# %%
# Define model architectures
def create_basic_cnn():
    model = Sequential([
        layers.Conv2D(32, 3, activation="relu", input_shape=(img_height, img_width, 3)),
        layers.MaxPooling2D(2),
        layers.Conv2D(64, 3, activation="relu"),
        layers.MaxPooling2D(2),
        layers.Conv2D(128, 3, activation="relu"),
        layers.MaxPooling2D(2),
        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.Dense(6, activation="softmax")
    ])
    return model

def create_advanced_cnn():
    model = Sequential([
        layers.Conv2D(32, 3, activation="relu", input_shape=(img_height, img_width, 3)),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2),
        layers.Conv2D(64, 3, activation="relu"),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2),
        layers.Conv2D(128, 3, activation="relu"),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2),
        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(6, activation="softmax")
    ])
    return model

def create_transfer_learning_model(base_model):
    for layer in base_model.layers:
        layer.trainable = False
    
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    output = layers.Dense(6, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

def create_resnet50_model():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
    return create_transfer_learning_model(base_model)

def create_vgg16_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
    return create_transfer_learning_model(base_model)

def create_mobilenetv2_model():
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
    return create_transfer_learning_model(base_model)

# %%
# Define K-fold cross-validation
n_splits = 5
kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# %%
def train_and_evaluate_model_cv(model_func, model_name):
    cv_scores = []
    
    for fold, (train_indices, val_indices) in enumerate(kfold.split(range(len(train_generator)))):
        print(f"Training {model_name} - Fold {fold + 1}/{n_splits}")
        
        # Create a new model for each fold
        model = model_func()
        model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
        
        # Create data generators for this fold
        train_data = train_datagen.flow_from_directory(
            train_dir,
            target_size=(img_height, img_width),
            batch_size=batch_size,
            class_mode="sparse",
            subset="training",
            shuffle=True,
            seed=42
        )
        val_data = train_datagen.flow_from_directory(
            train_dir,
            target_size=(img_height, img_width),
            batch_size=batch_size,
            class_mode="sparse",
            subset="validation",
            shuffle=True,
            seed=42
        )
        
        # Train the model
        history = model.fit(
            train_data,
            epochs=30,
            validation_data=val_data,
            callbacks=[
                keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
                keras.callbacks.ReduceLROnPlateau(factor=0.2, patience=3)
            ],
            verbose=1
        )
        
        # Evaluate the model
        val_loss, val_accuracy = model.evaluate(val_data)
        cv_scores.append(val_accuracy)
        
        print(f"Fold {fold + 1} - Validation Accuracy: {val_accuracy:.4f}")
        
        # Save the model
        model.save(f'model_{model_name}_fold_{fold+1}.h5')
    
    print(f"{model_name} - Average Validation Accuracy: {np.mean(cv_scores):.4f} (+/- {np.std(cv_scores):.4f})")
    
    # Train on full training data and evaluate on test data
    model = model_func()
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    history = model.fit(
        train_generator,
        epochs=30,
        validation_data=validation_generator,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
            keras.callbacks.ReduceLROnPlateau(factor=0.2, patience=3)
        ]
    )
    test_loss, test_accuracy = model.evaluate(test_generator)
    
    # Save the final model
    model.save(f'model_{model_name}_final.h5')
    
    return history, np.mean(cv_scores), np.std(cv_scores), test_accuracy

# %%
# Train and evaluate all models
results = {}

for model_name, model_func in {
    "Basic CNN": create_basic_cnn,
    "Advanced CNN": create_advanced_cnn,
    "ResNet50": create_resnet50_model,
    "VGG16": create_vgg16_model,
    "MobileNetV2": create_mobilenetv2_model
}.items():
    print(f"\nTraining {model_name}...")
    try:
        history, cv_mean, cv_std, test_accuracy = train_and_evaluate_model_cv(model_func, model_name)
        results[model_name] = {
            "history": history,
            "cv_mean": cv_mean,
            "cv_std": cv_std,
            "test_accuracy": test_accuracy
        }
        print(f"{model_name} - Test Accuracy: {test_accuracy:.4f}")
    except Exception as e:
        print(f"An error occurred while training {model_name}: {str(e)}")
# Out:
# Training Basic CNN...
# Training Basic CNN - Fold 1/5
# c:\users\abdul\appdata\local\programs\python\python39\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# c:\users\abdul\appdata\local\programs\python\python39\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 323s 899ms/step - accuracy: 0.4750 - loss: 1.3281 - val_accuracy: 0.6787 - val_loss: 0.8644 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 237s 670ms/step - accuracy: 0.6936 - loss: 0.8298 - val_accuracy: 0.7318 - val_loss: 0.7320 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 246s 694ms/step - accuracy: 0.7332 - loss: 0.7238 - val_accuracy: 0.7354 - val_loss: 0.7293 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 246s 694ms/step - accuracy: 0.7412 - loss: 0.6930 - val_accuracy: 0.7785 - val_loss: 0.6290 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 245s 692ms/step - accuracy: 0.7755 - loss: 0.6278 - val_accuracy: 0.7411 - val_loss: 0.7036 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 246s 693ms/step - accuracy: 0.7788 - loss: 0.5882 - val_accuracy: 0.7468 - val_loss: 0.7010 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 251s 709ms/step - accuracy: 0.7914 - loss: 0.5691 - val_accuracy: 0.7785 - val_loss: 0.6105 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 249s 704ms/step - accuracy: 0.7957 - loss: 0.5667 - val_accuracy: 0.8220 - val_loss: 0.5177 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 688ms/step - accuracy: 0.8129 - loss: 0.5193 - val_accuracy: 0.8206 - val_loss: 0.4842 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 231s 652ms/step - accuracy: 0.8192 - loss: 0.4926 - val_accuracy: 0.8188 - val_loss: 0.5130 - learning_rate: 0.0010
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 245s 690ms/step - accuracy: 0.8284 - loss: 0.4852 - val_accuracy: 0.7885 - val_loss: 0.5742 - learning_rate: 0.0010
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 213s 547ms/step - accuracy: 0.8359 - loss: 0.4555 - val_accuracy: 0.8181 - val_loss: 0.5017 - learning_rate: 0.0010
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 156s 440ms/step - accuracy: 0.8515 - loss: 0.4063 - val_accuracy: 0.8466 - val_loss: 0.4388 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 412ms/step - accuracy: 0.8582 - loss: 0.3755 - val_accuracy: 0.8474 - val_loss: 0.4325 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 142s 401ms/step - accuracy: 0.8668 - loss: 0.3629 - val_accuracy: 0.8538 - val_loss: 0.4134 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 417ms/step - accuracy: 0.8713 - loss: 0.3622 - val_accuracy: 0.8431 - val_loss: 0.4336 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 410ms/step - accuracy: 0.8671 - loss: 0.3630 - val_accuracy: 0.8534 - val_loss: 0.4158 - learning_rate: 2.0000e-04
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 141s 400ms/step - accuracy: 0.8745 - loss: 0.3500 - val_accuracy: 0.8527 - val_loss: 0.4051 - learning_rate: 2.0000e-04
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 137s 387ms/step - accuracy: 0.8708 - loss: 0.3536 - val_accuracy: 0.8566 - val_loss: 0.4039 - learning_rate: 2.0000e-04
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 148s 419ms/step - accuracy: 0.8762 - loss: 0.3371 - val_accuracy: 0.8524 - val_loss: 0.4118 - learning_rate: 2.0000e-04
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 136s 384ms/step - accuracy: 0.8726 - loss: 0.3473 - val_accuracy: 0.8595 - val_loss: 0.4133 - learning_rate: 2.0000e-04
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 140s 397ms/step - accuracy: 0.8822 - loss: 0.3315 - val_accuracy: 0.8570 - val_loss: 0.4158 - learning_rate: 2.0000e-04
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 143s 404ms/step - accuracy: 0.8823 - loss: 0.3272 - val_accuracy: 0.8666 - val_loss: 0.3903 - learning_rate: 4.0000e-05
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 140s 395ms/step - accuracy: 0.8857 - loss: 0.3181 - val_accuracy: 0.8666 - val_loss: 0.3974 - learning_rate: 4.0000e-05
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 137s 389ms/step - accuracy: 0.8891 - loss: 0.3118 - val_accuracy: 0.8659 - val_loss: 0.3936 - learning_rate: 4.0000e-05
# Epoch 26/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 137s 387ms/step - accuracy: 0.8958 - loss: 0.2915 - val_accuracy: 0.8720 - val_loss: 0.3880 - learning_rate: 4.0000e-05
# Epoch 27/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 133s 377ms/step - accuracy: 0.8914 - loss: 0.2998 - val_accuracy: 0.8634 - val_loss: 0.4040 - learning_rate: 4.0000e-05
# Epoch 28/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.8904 - loss: 0.2995 - val_accuracy: 0.8616 - val_loss: 0.3987 - learning_rate: 4.0000e-05
# Epoch 29/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8922 - loss: 0.2904 - val_accuracy: 0.8631 - val_loss: 0.3986 - learning_rate: 4.0000e-05
# Epoch 30/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 275s 781ms/step - accuracy: 0.8938 - loss: 0.2861 - val_accuracy: 0.8677 - val_loss: 0.3870 - learning_rate: 8.0000e-06
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 15s 166ms/step - accuracy: 0.8647 - loss: 0.3868
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 1 - Validation Accuracy: 0.8691
# Training Basic CNN - Fold 2/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 141s 395ms/step - accuracy: 0.4936 - loss: 1.3095 - val_accuracy: 0.6345 - val_loss: 0.9844 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 152s 429ms/step - accuracy: 0.6568 - loss: 0.8967 - val_accuracy: 0.6922 - val_loss: 0.8064 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 140s 396ms/step - accuracy: 0.7215 - loss: 0.7422 - val_accuracy: 0.7297 - val_loss: 0.7055 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 143s 405ms/step - accuracy: 0.7621 - loss: 0.6497 - val_accuracy: 0.7689 - val_loss: 0.6340 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 150s 424ms/step - accuracy: 0.7750 - loss: 0.6134 - val_accuracy: 0.7992 - val_loss: 0.5670 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 410ms/step - accuracy: 0.7974 - loss: 0.5659 - val_accuracy: 0.7971 - val_loss: 0.5659 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 149s 421ms/step - accuracy: 0.8086 - loss: 0.5322 - val_accuracy: 0.8174 - val_loss: 0.5257 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 143s 403ms/step - accuracy: 0.8126 - loss: 0.5254 - val_accuracy: 0.8170 - val_loss: 0.5141 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 140s 396ms/step - accuracy: 0.8185 - loss: 0.4996 - val_accuracy: 0.8124 - val_loss: 0.5160 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 141s 399ms/step - accuracy: 0.8309 - loss: 0.4703 - val_accuracy: 0.8281 - val_loss: 0.4846 - learning_rate: 0.0010
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 135s 382ms/step - accuracy: 0.8257 - loss: 0.4729 - val_accuracy: 0.8345 - val_loss: 0.4835 - learning_rate: 0.0010
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 130s 368ms/step - accuracy: 0.8315 - loss: 0.4572 - val_accuracy: 0.8188 - val_loss: 0.5151 - learning_rate: 0.0010
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 137s 387ms/step - accuracy: 0.8414 - loss: 0.4537 - val_accuracy: 0.8185 - val_loss: 0.5246 - learning_rate: 0.0010
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 408ms/step - accuracy: 0.8448 - loss: 0.4173 - val_accuracy: 0.8138 - val_loss: 0.5237 - learning_rate: 0.0010
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 125s 355ms/step - accuracy: 0.8683 - loss: 0.3690 - val_accuracy: 0.8520 - val_loss: 0.4166 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 126s 355ms/step - accuracy: 0.8782 - loss: 0.3330 - val_accuracy: 0.8591 - val_loss: 0.4143 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 125s 354ms/step - accuracy: 0.8827 - loss: 0.3324 - val_accuracy: 0.8695 - val_loss: 0.3904 - learning_rate: 2.0000e-04
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 351ms/step - accuracy: 0.8863 - loss: 0.3148 - val_accuracy: 0.8573 - val_loss: 0.3954 - learning_rate: 2.0000e-04
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.8850 - loss: 0.3197 - val_accuracy: 0.8527 - val_loss: 0.4186 - learning_rate: 2.0000e-04
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 351ms/step - accuracy: 0.8896 - loss: 0.3019 - val_accuracy: 0.8648 - val_loss: 0.3881 - learning_rate: 2.0000e-04
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 350ms/step - accuracy: 0.8870 - loss: 0.3045 - val_accuracy: 0.8609 - val_loss: 0.4082 - learning_rate: 2.0000e-04
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 349ms/step - accuracy: 0.8985 - loss: 0.2885 - val_accuracy: 0.8634 - val_loss: 0.3940 - learning_rate: 2.0000e-04
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 351ms/step - accuracy: 0.8933 - loss: 0.3005 - val_accuracy: 0.8559 - val_loss: 0.4131 - learning_rate: 2.0000e-04
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 349ms/step - accuracy: 0.9008 - loss: 0.2778 - val_accuracy: 0.8730 - val_loss: 0.3739 - learning_rate: 4.0000e-05
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.9022 - loss: 0.2629 - val_accuracy: 0.8713 - val_loss: 0.3941 - learning_rate: 4.0000e-05
# Epoch 26/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.8978 - loss: 0.2832 - val_accuracy: 0.8730 - val_loss: 0.3739 - learning_rate: 4.0000e-05
# Epoch 27/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 349ms/step - accuracy: 0.9010 - loss: 0.2769 - val_accuracy: 0.8709 - val_loss: 0.3773 - learning_rate: 4.0000e-05
# Epoch 28/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9317s 27s/step - accuracy: 0.9088 - loss: 0.2588 - val_accuracy: 0.8631 - val_loss: 0.3965 - learning_rate: 8.0000e-06
# Epoch 29/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 125s 354ms/step - accuracy: 0.9045 - loss: 0.2647 - val_accuracy: 0.8716 - val_loss: 0.3829 - learning_rate: 8.0000e-06
# Epoch 30/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 126s 356ms/step - accuracy: 0.9065 - loss: 0.2715 - val_accuracy: 0.8688 - val_loss: 0.3796 - learning_rate: 8.0000e-06
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 14s 164ms/step - accuracy: 0.8690 - loss: 0.3744
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 2 - Validation Accuracy: 0.8652
# Training Basic CNN - Fold 3/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 127s 354ms/step - accuracy: 0.4782 - loss: 1.3339 - val_accuracy: 0.6352 - val_loss: 0.9160 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 352ms/step - accuracy: 0.6656 - loss: 0.8793 - val_accuracy: 0.7015 - val_loss: 0.7849 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 350ms/step - accuracy: 0.7222 - loss: 0.7353 - val_accuracy: 0.7489 - val_loss: 0.6676 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.7588 - loss: 0.6617 - val_accuracy: 0.7618 - val_loss: 0.6535 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 4585s 13s/step - accuracy: 0.7732 - loss: 0.6134 - val_accuracy: 0.8010 - val_loss: 0.5733 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 126s 357ms/step - accuracy: 0.7946 - loss: 0.5654 - val_accuracy: 0.8010 - val_loss: 0.5587 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 125s 353ms/step - accuracy: 0.7970 - loss: 0.5621 - val_accuracy: 0.8088 - val_loss: 0.5706 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 128s 363ms/step - accuracy: 0.8054 - loss: 0.5322 - val_accuracy: 0.8014 - val_loss: 0.5679 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 138s 390ms/step - accuracy: 0.8073 - loss: 0.5165 - val_accuracy: 0.7978 - val_loss: 0.5875 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 409ms/step - accuracy: 0.8408 - loss: 0.4407 - val_accuracy: 0.8302 - val_loss: 0.4673 - learning_rate: 2.0000e-04
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 140s 395ms/step - accuracy: 0.8495 - loss: 0.4100 - val_accuracy: 0.8431 - val_loss: 0.4576 - learning_rate: 2.0000e-04
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 137s 387ms/step - accuracy: 0.8551 - loss: 0.3938 - val_accuracy: 0.8491 - val_loss: 0.4388 - learning_rate: 2.0000e-04
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 168s 475ms/step - accuracy: 0.8629 - loss: 0.3855 - val_accuracy: 0.8445 - val_loss: 0.4397 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 205s 577ms/step - accuracy: 0.8573 - loss: 0.3937 - val_accuracy: 0.8484 - val_loss: 0.4272 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 150s 424ms/step - accuracy: 0.8592 - loss: 0.3920 - val_accuracy: 0.8570 - val_loss: 0.4188 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 417ms/step - accuracy: 0.8676 - loss: 0.3776 - val_accuracy: 0.8509 - val_loss: 0.4292 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 149s 422ms/step - accuracy: 0.8676 - loss: 0.3626 - val_accuracy: 0.8484 - val_loss: 0.4204 - learning_rate: 2.0000e-04
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 151s 428ms/step - accuracy: 0.8639 - loss: 0.3686 - val_accuracy: 0.8573 - val_loss: 0.4140 - learning_rate: 2.0000e-04
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 150s 426ms/step - accuracy: 0.8690 - loss: 0.3514 - val_accuracy: 0.8534 - val_loss: 0.4188 - learning_rate: 2.0000e-04
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 150s 423ms/step - accuracy: 0.8742 - loss: 0.3368 - val_accuracy: 0.8598 - val_loss: 0.3892 - learning_rate: 2.0000e-04
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 151s 428ms/step - accuracy: 0.8764 - loss: 0.3397 - val_accuracy: 0.8516 - val_loss: 0.4135 - learning_rate: 2.0000e-04
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 150s 423ms/step - accuracy: 0.8760 - loss: 0.3301 - val_accuracy: 0.8609 - val_loss: 0.4156 - learning_rate: 2.0000e-04
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 149s 422ms/step - accuracy: 0.8781 - loss: 0.3335 - val_accuracy: 0.8563 - val_loss: 0.4169 - learning_rate: 2.0000e-04
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 149s 423ms/step - accuracy: 0.8844 - loss: 0.3155 - val_accuracy: 0.8591 - val_loss: 0.3960 - learning_rate: 4.0000e-05
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 151s 426ms/step - accuracy: 0.8894 - loss: 0.3086 - val_accuracy: 0.8666 - val_loss: 0.3801 - learning_rate: 4.0000e-05
# Epoch 26/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 154s 436ms/step - accuracy: 0.8899 - loss: 0.3047 - val_accuracy: 0.8673 - val_loss: 0.3856 - learning_rate: 4.0000e-05
# Epoch 27/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 153s 432ms/step - accuracy: 0.8802 - loss: 0.3185 - val_accuracy: 0.8588 - val_loss: 0.3914 - learning_rate: 4.0000e-05
# Epoch 28/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 407ms/step - accuracy: 0.8892 - loss: 0.3109 - val_accuracy: 0.8616 - val_loss: 0.3955 - learning_rate: 4.0000e-05
# Epoch 29/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 143s 403ms/step - accuracy: 0.8952 - loss: 0.2971 - val_accuracy: 0.8641 - val_loss: 0.3983 - learning_rate: 8.0000e-06
# Epoch 30/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 411ms/step - accuracy: 0.8902 - loss: 0.2949 - val_accuracy: 0.8663 - val_loss: 0.3839 - learning_rate: 8.0000e-06
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 15s 175ms/step - accuracy: 0.8613 - loss: 0.3818
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 3 - Validation Accuracy: 0.8634
# Training Basic CNN - Fold 4/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.4821 - loss: 1.2866 - val_accuracy: 0.6644 - val_loss: 0.8981 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 142s 402ms/step - accuracy: 0.6795 - loss: 0.8484 - val_accuracy: 0.7104 - val_loss: 0.7791 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 142s 402ms/step - accuracy: 0.7264 - loss: 0.7379 - val_accuracy: 0.7546 - val_loss: 0.6776 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 142s 401ms/step - accuracy: 0.7418 - loss: 0.6880 - val_accuracy: 0.7468 - val_loss: 0.6979 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 143s 404ms/step - accuracy: 0.7684 - loss: 0.6270 - val_accuracy: 0.7543 - val_loss: 0.6598 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 155s 438ms/step - accuracy: 0.7839 - loss: 0.5893 - val_accuracy: 0.7550 - val_loss: 0.6470 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 417ms/step - accuracy: 0.8011 - loss: 0.5457 - val_accuracy: 0.8063 - val_loss: 0.5637 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 128s 361ms/step - accuracy: 0.8057 - loss: 0.5328 - val_accuracy: 0.8117 - val_loss: 0.5481 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 128s 361ms/step - accuracy: 0.8195 - loss: 0.4818 - val_accuracy: 0.7867 - val_loss: 0.5862 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 133s 376ms/step - accuracy: 0.8188 - loss: 0.4964 - val_accuracy: 0.8185 - val_loss: 0.5174 - learning_rate: 0.0010
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 127s 359ms/step - accuracy: 0.8236 - loss: 0.4878 - val_accuracy: 0.8099 - val_loss: 0.5478 - learning_rate: 0.0010
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.8299 - loss: 0.4720 - val_accuracy: 0.8324 - val_loss: 0.4621 - learning_rate: 0.0010
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 130s 369ms/step - accuracy: 0.8380 - loss: 0.4421 - val_accuracy: 0.8174 - val_loss: 0.5353 - learning_rate: 0.0010
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 155s 440ms/step - accuracy: 0.8363 - loss: 0.4408 - val_accuracy: 0.8381 - val_loss: 0.4666 - learning_rate: 0.0010
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 181s 510ms/step - accuracy: 0.8511 - loss: 0.4157 - val_accuracy: 0.8242 - val_loss: 0.5124 - learning_rate: 0.0010
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 691ms/step - accuracy: 0.8580 - loss: 0.3862 - val_accuracy: 0.8502 - val_loss: 0.4286 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 131s 371ms/step - accuracy: 0.8727 - loss: 0.3455 - val_accuracy: 0.8595 - val_loss: 0.4085 - learning_rate: 2.0000e-04
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 349ms/step - accuracy: 0.8820 - loss: 0.3229 - val_accuracy: 0.8588 - val_loss: 0.4130 - learning_rate: 2.0000e-04
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 375ms/step - accuracy: 0.8737 - loss: 0.3286 - val_accuracy: 0.8466 - val_loss: 0.4230 - learning_rate: 2.0000e-04
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 127s 360ms/step - accuracy: 0.8826 - loss: 0.3186 - val_accuracy: 0.8702 - val_loss: 0.3897 - learning_rate: 2.0000e-04
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8814 - loss: 0.3215 - val_accuracy: 0.8545 - val_loss: 0.4296 - learning_rate: 2.0000e-04
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 127s 359ms/step - accuracy: 0.8827 - loss: 0.3260 - val_accuracy: 0.8645 - val_loss: 0.3877 - learning_rate: 2.0000e-04
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 131s 370ms/step - accuracy: 0.8920 - loss: 0.3052 - val_accuracy: 0.8531 - val_loss: 0.4084 - learning_rate: 2.0000e-04
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 131s 371ms/step - accuracy: 0.8870 - loss: 0.3067 - val_accuracy: 0.8556 - val_loss: 0.4083 - learning_rate: 2.0000e-04
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8872 - loss: 0.3086 - val_accuracy: 0.8652 - val_loss: 0.3922 - learning_rate: 2.0000e-04
# Epoch 26/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 374ms/step - accuracy: 0.8926 - loss: 0.2854 - val_accuracy: 0.8716 - val_loss: 0.3783 - learning_rate: 4.0000e-05
# Epoch 27/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 126s 358ms/step - accuracy: 0.9016 - loss: 0.2742 - val_accuracy: 0.8677 - val_loss: 0.3848 - learning_rate: 4.0000e-05
# Epoch 28/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8926 - loss: 0.2850 - val_accuracy: 0.8645 - val_loss: 0.3928 - learning_rate: 4.0000e-05
# Epoch 29/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.8991 - loss: 0.2768 - val_accuracy: 0.8666 - val_loss: 0.3838 - learning_rate: 4.0000e-05
# Epoch 30/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.9000 - loss: 0.2728 - val_accuracy: 0.8680 - val_loss: 0.3876 - learning_rate: 8.0000e-06
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 14s 158ms/step - accuracy: 0.8694 - loss: 0.3788
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 4 - Validation Accuracy: 0.8623
# Training Basic CNN - Fold 5/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 347ms/step - accuracy: 0.4746 - loss: 1.3354 - val_accuracy: 0.6259 - val_loss: 0.9518 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.6655 - loss: 0.8686 - val_accuracy: 0.6772 - val_loss: 0.8603 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 344ms/step - accuracy: 0.7058 - loss: 0.7889 - val_accuracy: 0.7436 - val_loss: 0.7015 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.7407 - loss: 0.6992 - val_accuracy: 0.7707 - val_loss: 0.6581 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.7676 - loss: 0.6513 - val_accuracy: 0.7436 - val_loss: 0.6999 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.7832 - loss: 0.5943 - val_accuracy: 0.7932 - val_loss: 0.5769 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.7956 - loss: 0.5507 - val_accuracy: 0.8092 - val_loss: 0.5446 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8058 - loss: 0.5367 - val_accuracy: 0.7621 - val_loss: 0.6422 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8009 - loss: 0.5348 - val_accuracy: 0.8302 - val_loss: 0.4891 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.8162 - loss: 0.5031 - val_accuracy: 0.8188 - val_loss: 0.5233 - learning_rate: 0.0010
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8301 - loss: 0.4728 - val_accuracy: 0.7989 - val_loss: 0.5652 - learning_rate: 0.0010
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 121s 343ms/step - accuracy: 0.8254 - loss: 0.4664 - val_accuracy: 0.7960 - val_loss: 0.5552 - learning_rate: 0.0010
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8617 - loss: 0.3898 - val_accuracy: 0.8481 - val_loss: 0.4173 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8646 - loss: 0.3706 - val_accuracy: 0.8538 - val_loss: 0.4240 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 121s 344ms/step - accuracy: 0.8674 - loss: 0.3552 - val_accuracy: 0.8545 - val_loss: 0.4181 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8685 - loss: 0.3530 - val_accuracy: 0.8524 - val_loss: 0.4187 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.8772 - loss: 0.3357 - val_accuracy: 0.8541 - val_loss: 0.4089 - learning_rate: 4.0000e-05
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8841 - loss: 0.3288 - val_accuracy: 0.8584 - val_loss: 0.4087 - learning_rate: 4.0000e-05
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8784 - loss: 0.3314 - val_accuracy: 0.8634 - val_loss: 0.4048 - learning_rate: 4.0000e-05
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 344ms/step - accuracy: 0.8793 - loss: 0.3220 - val_accuracy: 0.8655 - val_loss: 0.3779 - learning_rate: 4.0000e-05
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 344ms/step - accuracy: 0.8792 - loss: 0.3272 - val_accuracy: 0.8606 - val_loss: 0.4148 - learning_rate: 4.0000e-05
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8862 - loss: 0.3215 - val_accuracy: 0.8623 - val_loss: 0.4022 - learning_rate: 4.0000e-05
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8844 - loss: 0.3224 - val_accuracy: 0.8609 - val_loss: 0.4036 - learning_rate: 4.0000e-05
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.8815 - loss: 0.3275 - val_accuracy: 0.8641 - val_loss: 0.4040 - learning_rate: 8.0000e-06
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 345ms/step - accuracy: 0.8806 - loss: 0.3294 - val_accuracy: 0.8627 - val_loss: 0.3928 - learning_rate: 8.0000e-06
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 14s 157ms/step - accuracy: 0.8447 - loss: 0.4178
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 5 - Validation Accuracy: 0.8577
# Basic CNN - Average Validation Accuracy: 0.8636 (+/- 0.0037)
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 348ms/step - accuracy: 0.4900 - loss: 1.2987 - val_accuracy: 0.6762 - val_loss: 0.8796 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.6646 - loss: 0.8842 - val_accuracy: 0.6958 - val_loss: 0.8280 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.7193 - loss: 0.7432 - val_accuracy: 0.7340 - val_loss: 0.7026 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.7545 - loss: 0.6632 - val_accuracy: 0.7771 - val_loss: 0.6240 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.7777 - loss: 0.6201 - val_accuracy: 0.7546 - val_loss: 0.6503 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.7949 - loss: 0.5716 - val_accuracy: 0.8081 - val_loss: 0.5434 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.7971 - loss: 0.5548 - val_accuracy: 0.7800 - val_loss: 0.6323 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 349ms/step - accuracy: 0.7986 - loss: 0.5490 - val_accuracy: 0.8160 - val_loss: 0.5209 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8161 - loss: 0.5226 - val_accuracy: 0.7910 - val_loss: 0.5747 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8167 - loss: 0.5003 - val_accuracy: 0.8160 - val_loss: 0.5188 - learning_rate: 0.0010
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.8314 - loss: 0.4672 - val_accuracy: 0.8063 - val_loss: 0.5436 - learning_rate: 0.0010
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.8310 - loss: 0.4594 - val_accuracy: 0.8342 - val_loss: 0.4732 - learning_rate: 0.0010
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8292 - loss: 0.4626 - val_accuracy: 0.8288 - val_loss: 0.4906 - learning_rate: 0.0010
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8408 - loss: 0.4365 - val_accuracy: 0.8060 - val_loss: 0.5384 - learning_rate: 0.0010
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 124s 350ms/step - accuracy: 0.8428 - loss: 0.4349 - val_accuracy: 0.8317 - val_loss: 0.4701 - learning_rate: 0.0010
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.8427 - loss: 0.4306 - val_accuracy: 0.8224 - val_loss: 0.5126 - learning_rate: 0.0010
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.8499 - loss: 0.4082 - val_accuracy: 0.8459 - val_loss: 0.4514 - learning_rate: 0.0010
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8593 - loss: 0.3927 - val_accuracy: 0.8388 - val_loss: 0.4498 - learning_rate: 0.0010
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.8524 - loss: 0.3974 - val_accuracy: 0.8356 - val_loss: 0.4718 - learning_rate: 0.0010
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.8691 - loss: 0.3689 - val_accuracy: 0.8363 - val_loss: 0.4743 - learning_rate: 0.0010
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 349ms/step - accuracy: 0.8620 - loss: 0.3805 - val_accuracy: 0.8466 - val_loss: 0.4324 - learning_rate: 0.0010
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.8631 - loss: 0.3755 - val_accuracy: 0.8477 - val_loss: 0.4666 - learning_rate: 0.0010
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8739 - loss: 0.3545 - val_accuracy: 0.8470 - val_loss: 0.4459 - learning_rate: 0.0010
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8747 - loss: 0.3394 - val_accuracy: 0.8363 - val_loss: 0.4677 - learning_rate: 0.0010
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8866 - loss: 0.3061 - val_accuracy: 0.8663 - val_loss: 0.3767 - learning_rate: 2.0000e-04
# Epoch 26/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 347ms/step - accuracy: 0.8964 - loss: 0.2782 - val_accuracy: 0.8770 - val_loss: 0.3658 - learning_rate: 2.0000e-04
# Epoch 27/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.8977 - loss: 0.2749 - val_accuracy: 0.8691 - val_loss: 0.3696 - learning_rate: 2.0000e-04
# Epoch 28/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 348ms/step - accuracy: 0.9073 - loss: 0.2599 - val_accuracy: 0.8663 - val_loss: 0.3653 - learning_rate: 2.0000e-04
# Epoch 29/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 349ms/step - accuracy: 0.9063 - loss: 0.2569 - val_accuracy: 0.8652 - val_loss: 0.3836 - learning_rate: 2.0000e-04
# Epoch 30/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 123s 349ms/step - accuracy: 0.8985 - loss: 0.2707 - val_accuracy: 0.8648 - val_loss: 0.3877 - learning_rate: 2.0000e-04
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 23s 245ms/step - accuracy: 0.8799 - loss: 0.3402
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Basic CNN - Test Accuracy: 0.8757
#
# Training Advanced CNN...
# Training Advanced CNN - Fold 1/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 221s 621ms/step - accuracy: 0.4010 - loss: 4.9355 - val_accuracy: 0.2700 - val_loss: 2.5542 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 218s 618ms/step - accuracy: 0.4653 - loss: 1.3589 - val_accuracy: 0.5260 - val_loss: 1.1088 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 218s 619ms/step - accuracy: 0.5104 - loss: 1.2249 - val_accuracy: 0.6209 - val_loss: 1.1159 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 218s 619ms/step - accuracy: 0.5245 - loss: 1.1998 - val_accuracy: 0.5902 - val_loss: 1.1478 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 218s 620ms/step - accuracy: 0.5686 - loss: 1.1180 - val_accuracy: 0.6320 - val_loss: 1.0768 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 239s 678ms/step - accuracy: 0.5849 - loss: 1.0763 - val_accuracy: 0.4854 - val_loss: 1.5519 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 227s 644ms/step - accuracy: 0.5995 - loss: 1.0463 - val_accuracy: 0.3877 - val_loss: 1.5803 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 228s 647ms/step - accuracy: 0.6114 - loss: 1.0161 - val_accuracy: 0.5774 - val_loss: 1.1285 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 221s 627ms/step - accuracy: 0.6541 - loss: 0.8842 - val_accuracy: 0.7650 - val_loss: 0.6709 - learning_rate: 2.0000e-04
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 222s 629ms/step - accuracy: 0.6686 - loss: 0.8455 - val_accuracy: 0.7867 - val_loss: 0.6828 - learning_rate: 2.0000e-04
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 622ms/step - accuracy: 0.6885 - loss: 0.8125 - val_accuracy: 0.7425 - val_loss: 0.7720 - learning_rate: 2.0000e-04
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 625ms/step - accuracy: 0.7039 - loss: 0.7776 - val_accuracy: 0.7771 - val_loss: 0.6465 - learning_rate: 2.0000e-04
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 623ms/step - accuracy: 0.7089 - loss: 0.7476 - val_accuracy: 0.7803 - val_loss: 0.6223 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 622ms/step - accuracy: 0.7101 - loss: 0.7600 - val_accuracy: 0.7867 - val_loss: 0.6362 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 623ms/step - accuracy: 0.7224 - loss: 0.7325 - val_accuracy: 0.7864 - val_loss: 0.6260 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 232s 658ms/step - accuracy: 0.7185 - loss: 0.7490 - val_accuracy: 0.8192 - val_loss: 0.5477 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 229s 649ms/step - accuracy: 0.7452 - loss: 0.7019 - val_accuracy: 0.8170 - val_loss: 0.5577 - learning_rate: 2.0000e-04
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 238s 675ms/step - accuracy: 0.7490 - loss: 0.6811 - val_accuracy: 0.8210 - val_loss: 0.5238 - learning_rate: 2.0000e-04
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 223s 633ms/step - accuracy: 0.7612 - loss: 0.6517 - val_accuracy: 0.8163 - val_loss: 0.5471 - learning_rate: 2.0000e-04
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 224s 634ms/step - accuracy: 0.7616 - loss: 0.6507 - val_accuracy: 0.8092 - val_loss: 0.5505 - learning_rate: 2.0000e-04
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 221s 626ms/step - accuracy: 0.7673 - loss: 0.6316 - val_accuracy: 0.7974 - val_loss: 0.5939 - learning_rate: 2.0000e-04
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 625ms/step - accuracy: 0.7697 - loss: 0.6309 - val_accuracy: 0.8388 - val_loss: 0.5043 - learning_rate: 4.0000e-05
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 222s 631ms/step - accuracy: 0.7879 - loss: 0.5782 - val_accuracy: 0.8335 - val_loss: 0.4904 - learning_rate: 4.0000e-05
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 248s 705ms/step - accuracy: 0.7872 - loss: 0.5904 - val_accuracy: 0.8395 - val_loss: 0.4643 - learning_rate: 4.0000e-05
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 253s 717ms/step - accuracy: 0.7934 - loss: 0.5621 - val_accuracy: 0.8388 - val_loss: 0.4631 - learning_rate: 4.0000e-05
# Epoch 26/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 232s 657ms/step - accuracy: 0.7999 - loss: 0.5560 - val_accuracy: 0.8438 - val_loss: 0.4704 - learning_rate: 4.0000e-05
# Epoch 27/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 248s 705ms/step - accuracy: 0.7886 - loss: 0.5890 - val_accuracy: 0.8481 - val_loss: 0.4607 - learning_rate: 4.0000e-05
# Epoch 28/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 240s 680ms/step - accuracy: 0.7936 - loss: 0.5691 - val_accuracy: 0.8459 - val_loss: 0.4585 - learning_rate: 4.0000e-05
# Epoch 29/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 233s 661ms/step - accuracy: 0.8038 - loss: 0.5441 - val_accuracy: 0.8413 - val_loss: 0.4621 - learning_rate: 4.0000e-05
# Epoch 30/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 226s 641ms/step - accuracy: 0.8074 - loss: 0.5420 - val_accuracy: 0.8481 - val_loss: 0.4516 - learning_rate: 4.0000e-05
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.8376 - loss: 0.4482
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 1 - Validation Accuracy: 0.8402
# Training Advanced CNN - Fold 2/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 221s 621ms/step - accuracy: 0.3833 - loss: 5.3157 - val_accuracy: 0.3124 - val_loss: 2.8296 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 621ms/step - accuracy: 0.4773 - loss: 1.3846 - val_accuracy: 0.4412 - val_loss: 1.2832 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 621ms/step - accuracy: 0.5021 - loss: 1.2648 - val_accuracy: 0.3716 - val_loss: 1.5394 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 623ms/step - accuracy: 0.5594 - loss: 1.1272 - val_accuracy: 0.5859 - val_loss: 1.1424 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 218s 620ms/step - accuracy: 0.5818 - loss: 1.0693 - val_accuracy: 0.5638 - val_loss: 1.4324 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 218s 619ms/step - accuracy: 0.6171 - loss: 1.0017 - val_accuracy: 0.6619 - val_loss: 0.9466 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 621ms/step - accuracy: 0.6360 - loss: 0.9650 - val_accuracy: 0.6394 - val_loss: 0.9746 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 621ms/step - accuracy: 0.6296 - loss: 0.9988 - val_accuracy: 0.6298 - val_loss: 0.9300 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 622ms/step - accuracy: 0.6554 - loss: 0.9524 - val_accuracy: 0.7400 - val_loss: 0.7859 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 621ms/step - accuracy: 0.6837 - loss: 0.8783 - val_accuracy: 0.5417 - val_loss: 1.4773 - learning_rate: 0.0010
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 621ms/step - accuracy: 0.6884 - loss: 0.8687 - val_accuracy: 0.7272 - val_loss: 0.8557 - learning_rate: 0.0010
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 623ms/step - accuracy: 0.7083 - loss: 0.8356 - val_accuracy: 0.7183 - val_loss: 0.8430 - learning_rate: 0.0010
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 624ms/step - accuracy: 0.7371 - loss: 0.7393 - val_accuracy: 0.8074 - val_loss: 0.5656 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 232s 660ms/step - accuracy: 0.7538 - loss: 0.6915 - val_accuracy: 0.8188 - val_loss: 0.5446 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 224s 634ms/step - accuracy: 0.7612 - loss: 0.6774 - val_accuracy: 0.8338 - val_loss: 0.5047 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 625ms/step - accuracy: 0.7679 - loss: 0.6543 - val_accuracy: 0.8252 - val_loss: 0.5007 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 621ms/step - accuracy: 0.7750 - loss: 0.6330 - val_accuracy: 0.8352 - val_loss: 0.5092 - learning_rate: 2.0000e-04
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 622ms/step - accuracy: 0.7735 - loss: 0.6406 - val_accuracy: 0.8106 - val_loss: 0.5396 - learning_rate: 2.0000e-04
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 620ms/step - accuracy: 0.7724 - loss: 0.6363 - val_accuracy: 0.8042 - val_loss: 0.5454 - learning_rate: 2.0000e-04
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 623ms/step - accuracy: 0.7858 - loss: 0.5877 - val_accuracy: 0.8484 - val_loss: 0.4572 - learning_rate: 4.0000e-05
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 623ms/step - accuracy: 0.7919 - loss: 0.5946 - val_accuracy: 0.8402 - val_loss: 0.4619 - learning_rate: 4.0000e-05
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 622ms/step - accuracy: 0.7940 - loss: 0.5768 - val_accuracy: 0.8442 - val_loss: 0.4643 - learning_rate: 4.0000e-05
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 623ms/step - accuracy: 0.7979 - loss: 0.5829 - val_accuracy: 0.8413 - val_loss: 0.4702 - learning_rate: 4.0000e-05
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 624ms/step - accuracy: 0.7941 - loss: 0.5913 - val_accuracy: 0.8474 - val_loss: 0.4502 - learning_rate: 8.0000e-06
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 623ms/step - accuracy: 0.7946 - loss: 0.5943 - val_accuracy: 0.8491 - val_loss: 0.4498 - learning_rate: 8.0000e-06
# Epoch 26/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 622ms/step - accuracy: 0.8020 - loss: 0.5653 - val_accuracy: 0.8488 - val_loss: 0.4504 - learning_rate: 8.0000e-06
# Epoch 27/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 623ms/step - accuracy: 0.7980 - loss: 0.5554 - val_accuracy: 0.8470 - val_loss: 0.4565 - learning_rate: 8.0000e-06
# Epoch 28/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 624ms/step - accuracy: 0.7973 - loss: 0.5661 - val_accuracy: 0.8477 - val_loss: 0.4499 - learning_rate: 8.0000e-06
# Epoch 29/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 624ms/step - accuracy: 0.7998 - loss: 0.5569 - val_accuracy: 0.8466 - val_loss: 0.4514 - learning_rate: 1.6000e-06
# Epoch 30/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 220s 623ms/step - accuracy: 0.7989 - loss: 0.5746 - val_accuracy: 0.8424 - val_loss: 0.4539 - learning_rate: 1.6000e-06
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.8426 - loss: 0.4625
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 2 - Validation Accuracy: 0.8506
# Training Advanced CNN - Fold 3/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 221s 621ms/step - accuracy: 0.3850 - loss: 5.1595 - val_accuracy: 0.2639 - val_loss: 4.9777 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 621ms/step - accuracy: 0.4435 - loss: 1.3534 - val_accuracy: 0.4315 - val_loss: 1.7060 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 622ms/step - accuracy: 0.4824 - loss: 1.2875 - val_accuracy: 0.4861 - val_loss: 1.3998 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 221s 627ms/step - accuracy: 0.5358 - loss: 1.1481 - val_accuracy: 0.5581 - val_loss: 1.1765 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 219s 622ms/step - accuracy: 0.5598 - loss: 1.1098 - val_accuracy: 0.4911 - val_loss: 1.5810 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 238s 676ms/step - accuracy: 0.5624 - loss: 1.1112 - val_accuracy: 0.5877 - val_loss: 1.1508 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 236s 671ms/step - accuracy: 0.5839 - loss: 1.0477 - val_accuracy: 0.5271 - val_loss: 1.2344 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 270s 767ms/step - accuracy: 0.6010 - loss: 1.0046 - val_accuracy: 0.6398 - val_loss: 1.0190 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 282s 801ms/step - accuracy: 0.6132 - loss: 0.9623 - val_accuracy: 0.7047 - val_loss: 0.8364 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 282s 801ms/step - accuracy: 0.6025 - loss: 0.9831 - val_accuracy: 0.4761 - val_loss: 2.1809 - learning_rate: 0.0010
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 277s 787ms/step - accuracy: 0.6318 - loss: 0.9627 - val_accuracy: 0.6152 - val_loss: 1.0580 - learning_rate: 0.0010
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 283s 803ms/step - accuracy: 0.6376 - loss: 0.9425 - val_accuracy: 0.5250 - val_loss: 1.4228 - learning_rate: 0.0010
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 277s 787ms/step - accuracy: 0.6831 - loss: 0.8331 - val_accuracy: 0.8039 - val_loss: 0.5845 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 282s 799ms/step - accuracy: 0.6812 - loss: 0.7915 - val_accuracy: 0.8081 - val_loss: 0.5748 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 279s 792ms/step - accuracy: 0.7031 - loss: 0.7624 - val_accuracy: 0.8074 - val_loss: 0.5590 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 271s 770ms/step - accuracy: 0.7072 - loss: 0.7478 - val_accuracy: 0.8149 - val_loss: 0.5531 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 261s 742ms/step - accuracy: 0.7159 - loss: 0.7354 - val_accuracy: 0.7525 - val_loss: 0.6675 - learning_rate: 2.0000e-04
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 264s 748ms/step - accuracy: 0.7320 - loss: 0.7120 - val_accuracy: 0.7989 - val_loss: 0.5910 - learning_rate: 2.0000e-04
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 269s 763ms/step - accuracy: 0.7317 - loss: 0.7130 - val_accuracy: 0.8170 - val_loss: 0.5289 - learning_rate: 2.0000e-04
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 263s 745ms/step - accuracy: 0.7333 - loss: 0.7046 - val_accuracy: 0.8014 - val_loss: 0.6686 - learning_rate: 2.0000e-04
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 263s 745ms/step - accuracy: 0.7578 - loss: 0.6675 - val_accuracy: 0.8188 - val_loss: 0.5160 - learning_rate: 2.0000e-04
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 261s 740ms/step - accuracy: 0.7526 - loss: 0.6581 - val_accuracy: 0.8281 - val_loss: 0.5386 - learning_rate: 2.0000e-04
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 262s 743ms/step - accuracy: 0.7691 - loss: 0.6559 - val_accuracy: 0.7935 - val_loss: 0.5934 - learning_rate: 2.0000e-04
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 262s 744ms/step - accuracy: 0.7663 - loss: 0.6386 - val_accuracy: 0.7999 - val_loss: 0.5692 - learning_rate: 2.0000e-04
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 262s 743ms/step - accuracy: 0.7732 - loss: 0.6305 - val_accuracy: 0.8491 - val_loss: 0.4497 - learning_rate: 4.0000e-05
# Epoch 26/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 261s 741ms/step - accuracy: 0.7828 - loss: 0.6020 - val_accuracy: 0.8527 - val_loss: 0.4626 - learning_rate: 4.0000e-05
# Epoch 27/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 264s 749ms/step - accuracy: 0.7835 - loss: 0.6042 - val_accuracy: 0.8466 - val_loss: 0.4599 - learning_rate: 4.0000e-05
# Epoch 28/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 266s 755ms/step - accuracy: 0.7912 - loss: 0.5878 - val_accuracy: 0.8456 - val_loss: 0.4588 - learning_rate: 4.0000e-05
# Epoch 29/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 258s 734ms/step - accuracy: 0.7912 - loss: 0.5876 - val_accuracy: 0.8520 - val_loss: 0.4440 - learning_rate: 8.0000e-06
# Epoch 30/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 691ms/step - accuracy: 0.7819 - loss: 0.5966 - val_accuracy: 0.8516 - val_loss: 0.4442 - learning_rate: 8.0000e-06
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 17s 192ms/step - accuracy: 0.8467 - loss: 0.4505
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 3 - Validation Accuracy: 0.8449
# Training Advanced CNN - Fold 4/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 250s 705ms/step - accuracy: 0.4017 - loss: 5.3535 - val_accuracy: 0.3078 - val_loss: 1.9020 - learning_rate: 0.0010
# Epoch 2/30
# ...
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8905 - loss: 0.2886 - val_accuracy: 0.8845 - val_loss: 0.3376 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8966 - loss: 0.2790 - val_accuracy: 0.8627 - val_loss: 0.3787 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.9015 - loss: 0.2614 - val_accuracy: 0.8880 - val_loss: 0.3074 - learning_rate: 2.0000e-04
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.9022 - loss: 0.2563 - val_accuracy: 0.8898 - val_loss: 0.3043 - learning_rate: 2.0000e-04
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 130s 367ms/step - accuracy: 0.9058 - loss: 0.2438 - val_accuracy: 0.8820 - val_loss: 0.3251 - learning_rate: 2.0000e-04
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 130s 367ms/step - accuracy: 0.9101 - loss: 0.2368 - val_accuracy: 0.8827 - val_loss: 0.3168 - learning_rate: 2.0000e-04
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.9073 - loss: 0.2314 - val_accuracy: 0.8919 - val_loss: 0.2996 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.9173 - loss: 0.2244 - val_accuracy: 0.8884 - val_loss: 0.3120 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.9129 - loss: 0.2217 - val_accuracy: 0.8884 - val_loss: 0.3212 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.9179 - loss: 0.2178 - val_accuracy: 0.8873 - val_loss: 0.3230 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.9225 - loss: 0.2075 - val_accuracy: 0.8927 - val_loss: 0.3140 - learning_rate: 4.0000e-05
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.9195 - loss: 0.2122 - val_accuracy: 0.8877 - val_loss: 0.3012 - learning_rate: 4.0000e-05
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - accuracy: 0.8917 - loss: 0.2854
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 3 - Validation Accuracy: 0.8873
# Training MobileNetV2 - Fold 4/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 134s 369ms/step - accuracy: 0.7549 - loss: 0.6780 - val_accuracy: 0.8581 - val_loss: 0.3936 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8606 - loss: 0.3804 - val_accuracy: 0.8545 - val_loss: 0.4143 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 372ms/step - accuracy: 0.8716 - loss: 0.3503 - val_accuracy: 0.8720 - val_loss: 0.3330 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 128s 363ms/step - accuracy: 0.8836 - loss: 0.3215 - val_accuracy: 0.8755 - val_loss: 0.3450 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.8864 - loss: 0.3020 - val_accuracy: 0.8777 - val_loss: 0.3310 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8836 - loss: 0.3168 - val_accuracy: 0.8802 - val_loss: 0.3263 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8880 - loss: 0.2943 - val_accuracy: 0.8809 - val_loss: 0.3358 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.8946 - loss: 0.2836 - val_accuracy: 0.8709 - val_loss: 0.3665 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8879 - loss: 0.2955 - val_accuracy: 0.8827 - val_loss: 0.3203 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 131s 371ms/step - accuracy: 0.8953 - loss: 0.2865 - val_accuracy: 0.8823 - val_loss: 0.3291 - learning_rate: 0.0010
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.9044 - loss: 0.2608 - val_accuracy: 0.8688 - val_loss: 0.3464 - learning_rate: 0.0010
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.8999 - loss: 0.2650 - val_accuracy: 0.8798 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.9144 - loss: 0.2331 - val_accuracy: 0.8841 - val_loss: 0.3170 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.9193 - loss: 0.2202 - val_accuracy: 0.8873 - val_loss: 0.3149 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.9071 - loss: 0.2340 - val_accuracy: 0.8887 - val_loss: 0.3239 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.9241 - loss: 0.2042 - val_accuracy: 0.8855 - val_loss: 0.3171 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.9193 - loss: 0.2121 - val_accuracy: 0.8919 - val_loss: 0.3177 - learning_rate: 2.0000e-04
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 135s 382ms/step - accuracy: 0.9194 - loss: 0.2125 - val_accuracy: 0.8934 - val_loss: 0.3036 - learning_rate: 4.0000e-05
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 133s 377ms/step - accuracy: 0.9176 - loss: 0.2059 - val_accuracy: 0.8927 - val_loss: 0.3135 - learning_rate: 4.0000e-05
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 131s 370ms/step - accuracy: 0.9279 - loss: 0.1979 - val_accuracy: 0.8862 - val_loss: 0.3197 - learning_rate: 4.0000e-05
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 131s 370ms/step - accuracy: 0.9190 - loss: 0.2049 - val_accuracy: 0.8859 - val_loss: 0.2994 - learning_rate: 4.0000e-05
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 374ms/step - accuracy: 0.9213 - loss: 0.2022 - val_accuracy: 0.8866 - val_loss: 0.3212 - learning_rate: 4.0000e-05
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 372ms/step - accuracy: 0.9256 - loss: 0.2005 - val_accuracy: 0.8937 - val_loss: 0.3067 - learning_rate: 4.0000e-05
# Epoch 24/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 137s 388ms/step - accuracy: 0.9239 - loss: 0.1957 - val_accuracy: 0.8830 - val_loss: 0.3248 - learning_rate: 4.0000e-05
# Epoch 25/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 133s 378ms/step - accuracy: 0.9230 - loss: 0.2062 - val_accuracy: 0.8984 - val_loss: 0.2998 - learning_rate: 8.0000e-06
# Epoch 26/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 131s 370ms/step - accuracy: 0.9295 - loss: 0.1919 - val_accuracy: 0.8962 - val_loss: 0.2908 - learning_rate: 8.0000e-06
# Epoch 27/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 372ms/step - accuracy: 0.9252 - loss: 0.2020 - val_accuracy: 0.8866 - val_loss: 0.3087 - learning_rate: 8.0000e-06
# Epoch 28/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 374ms/step - accuracy: 0.9225 - loss: 0.2034 - val_accuracy: 0.8887 - val_loss: 0.3052 - learning_rate: 8.0000e-06
# Epoch 29/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 131s 370ms/step - accuracy: 0.9281 - loss: 0.1907 - val_accuracy: 0.8820 - val_loss: 0.3210 - learning_rate: 8.0000e-06
# Epoch 30/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 373ms/step - accuracy: 0.9262 - loss: 0.2029 - val_accuracy: 0.8955 - val_loss: 0.3076 - learning_rate: 1.6000e-06
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 298ms/step - accuracy: 0.8898 - loss: 0.3047
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 4 - Validation Accuracy: 0.8852
# Training MobileNetV2 - Fold 5/5
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 135s 371ms/step - accuracy: 0.7622 - loss: 0.6466 - val_accuracy: 0.8581 - val_loss: 0.3735 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 130s 367ms/step - accuracy: 0.8577 - loss: 0.3840 - val_accuracy: 0.8684 - val_loss: 0.3721 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8756 - loss: 0.3407 - val_accuracy: 0.8620 - val_loss: 0.3621 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.8769 - loss: 0.3313 - val_accuracy: 0.8634 - val_loss: 0.3540 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.8834 - loss: 0.3226 - val_accuracy: 0.8816 - val_loss: 0.3449 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8913 - loss: 0.2998 - val_accuracy: 0.8616 - val_loss: 0.3613 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 365ms/step - accuracy: 0.8863 - loss: 0.2957 - val_accuracy: 0.8823 - val_loss: 0.3273 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8936 - loss: 0.2782 - val_accuracy: 0.8812 - val_loss: 0.3271 - learning_rate: 0.0010
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 364ms/step - accuracy: 0.8978 - loss: 0.2735 - val_accuracy: 0.8698 - val_loss: 0.3645 - learning_rate: 0.0010
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.8971 - loss: 0.2711 - val_accuracy: 0.8780 - val_loss: 0.3396 - learning_rate: 0.0010
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 140s 396ms/step - accuracy: 0.9015 - loss: 0.2705 - val_accuracy: 0.8705 - val_loss: 0.3557 - learning_rate: 0.0010
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 139s 393ms/step - accuracy: 0.9067 - loss: 0.2423 - val_accuracy: 0.8812 - val_loss: 0.3300 - learning_rate: 2.0000e-04
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 140s 397ms/step - accuracy: 0.9178 - loss: 0.2190 - val_accuracy: 0.8894 - val_loss: 0.3040 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 133s 377ms/step - accuracy: 0.9136 - loss: 0.2297 - val_accuracy: 0.8773 - val_loss: 0.3158 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 131s 371ms/step - accuracy: 0.9172 - loss: 0.2257 - val_accuracy: 0.8834 - val_loss: 0.3088 - learning_rate: 2.0000e-04
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 130s 369ms/step - accuracy: 0.9197 - loss: 0.2150 - val_accuracy: 0.8877 - val_loss: 0.3167 - learning_rate: 2.0000e-04
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 375ms/step - accuracy: 0.9176 - loss: 0.2145 - val_accuracy: 0.8902 - val_loss: 0.3138 - learning_rate: 4.0000e-05
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 130s 366ms/step - accuracy: 0.9182 - loss: 0.2144 - val_accuracy: 0.8927 - val_loss: 0.2965 - learning_rate: 4.0000e-05
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 130s 368ms/step - accuracy: 0.9191 - loss: 0.2164 - val_accuracy: 0.8973 - val_loss: 0.3058 - learning_rate: 4.0000e-05
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 133s 377ms/step - accuracy: 0.9227 - loss: 0.1985 - val_accuracy: 0.8909 - val_loss: 0.3076 - learning_rate: 4.0000e-05
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 133s 375ms/step - accuracy: 0.9176 - loss: 0.2166 - val_accuracy: 0.8916 - val_loss: 0.2990 - learning_rate: 4.0000e-05
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 149s 423ms/step - accuracy: 0.9222 - loss: 0.2038 - val_accuracy: 0.8855 - val_loss: 0.3187 - learning_rate: 8.0000e-06
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 416ms/step - accuracy: 0.9279 - loss: 0.1998 - val_accuracy: 0.8919 - val_loss: 0.3085 - learning_rate: 8.0000e-06
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 29s 331ms/step - accuracy: 0.8694 - loss: 0.3361
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 5 - Validation Accuracy: 0.8787
# MobileNetV2 - Average Validation Accuracy: 0.8847 (+/- 0.0033)
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 150s 415ms/step - accuracy: 0.7677 - loss: 0.6560 - val_accuracy: 0.8673 - val_loss: 0.3640 - learning_rate: 0.0010
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 137s 387ms/step - accuracy: 0.8582 - loss: 0.3750 - val_accuracy: 0.8645 - val_loss: 0.3718 - learning_rate: 0.0010
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 133s 376ms/step - accuracy: 0.8646 - loss: 0.3491 - val_accuracy: 0.8524 - val_loss: 0.3895 - learning_rate: 0.0010
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 135s 381ms/step - accuracy: 0.8810 - loss: 0.3295 - val_accuracy: 0.8659 - val_loss: 0.3550 - learning_rate: 0.0010
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 134s 378ms/step - accuracy: 0.8818 - loss: 0.3080 - val_accuracy: 0.8666 - val_loss: 0.3593 - learning_rate: 0.0010
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 132s 373ms/step - accuracy: 0.8870 - loss: 0.2949 - val_accuracy: 0.8684 - val_loss: 0.3596 - learning_rate: 0.0010
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 134s 380ms/step - accuracy: 0.8855 - loss: 0.2997 - val_accuracy: 0.8663 - val_loss: 0.3764 - learning_rate: 0.0010
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 133s 375ms/step - accuracy: 0.8973 - loss: 0.2635 - val_accuracy: 0.8784 - val_loss: 0.3250 - learning_rate: 2.0000e-04
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 136s 385ms/step - accuracy: 0.9077 - loss: 0.2420 - val_accuracy: 0.8802 - val_loss: 0.3164 - learning_rate: 2.0000e-04
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 136s 383ms/step - accuracy: 0.9075 - loss: 0.2519 - val_accuracy: 0.8812 - val_loss: 0.3334 - learning_rate: 2.0000e-04
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 134s 378ms/step - accuracy: 0.9076 - loss: 0.2414 - val_accuracy: 0.8891 - val_loss: 0.3097 - learning_rate: 2.0000e-04
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 140s 395ms/step - accuracy: 0.9139 - loss: 0.2352 - val_accuracy: 0.8830 - val_loss: 0.3254 - learning_rate: 2.0000e-04
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 406ms/step - accuracy: 0.9080 - loss: 0.2505 - val_accuracy: 0.8877 - val_loss: 0.3169 - learning_rate: 2.0000e-04
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 409ms/step - accuracy: 0.9141 - loss: 0.2273 - val_accuracy: 0.8780 - val_loss: 0.3298 - learning_rate: 2.0000e-04
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 407ms/step - accuracy: 0.9170 - loss: 0.2191 - val_accuracy: 0.8795 - val_loss: 0.3285 - learning_rate: 4.0000e-05
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 409ms/step - accuracy: 0.9173 - loss: 0.2198 - val_accuracy: 0.8873 - val_loss: 0.3006 - learning_rate: 4.0000e-05
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 411ms/step - accuracy: 0.9182 - loss: 0.2180 - val_accuracy: 0.8809 - val_loss: 0.3111 - learning_rate: 4.0000e-05
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 408ms/step - accuracy: 0.9165 - loss: 0.2186 - val_accuracy: 0.8905 - val_loss: 0.2937 - learning_rate: 4.0000e-05
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 143s 404ms/step - accuracy: 0.9174 - loss: 0.2202 - val_accuracy: 0.8930 - val_loss: 0.3008 - learning_rate: 4.0000e-05
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 407ms/step - accuracy: 0.9136 - loss: 0.2261 - val_accuracy: 0.8934 - val_loss: 0.2937 - learning_rate: 4.0000e-05
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 410ms/step - accuracy: 0.9141 - loss: 0.2244 - val_accuracy: 0.8816 - val_loss: 0.3267 - learning_rate: 4.0000e-05
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 416ms/step - accuracy: 0.9182 - loss: 0.2139 - val_accuracy: 0.8909 - val_loss: 0.3022 - learning_rate: 8.0000e-06
# Epoch 23/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 143s 406ms/step - accuracy: 0.9203 - loss: 0.2081 - val_accuracy: 0.8937 - val_loss: 0.2938 - learning_rate: 8.0000e-06
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 41s 440ms/step - accuracy: 0.8953 - loss: 0.2600
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# MobileNetV2 - Test Accuracy: 0.9017

# %%
# Visualization functions
def plot_training_history(results):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
    
    for model_name, result in results.items():
        ax1.plot(result['history'].history['accuracy'], label=f'{model_name} (Train)')
        ax1.plot(result['history'].history['val_accuracy'], label=f'{model_name} (Val)')
    ax1.set_title('Model Accuracy')
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.legend()
    
    for model_name, result in results.items():
        ax2.plot(result['history'].history['loss'], label=f'{model_name} (Train)')
        ax2.plot(result['history'].history['val_loss'], label=f'{model_name} (Val)')
    ax2.set_title('Model Loss')
    ax2.set_ylabel('Loss')
    ax2.set_xlabel('Epoch')
    ax2.legend()
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.close()

def plot_test_accuracy(results):
    model_names = list(results.keys())
    test_accuracies = [result['test_accuracy'] for result in results.values()]
    cv_means = [result['cv_mean'] for result in results.values()]
    cv_stds = [result['cv_std'] for result in results.values()]
    
    x = np.arange(len(model_names))
    width = 0.35
    
    fig, ax = plt.subplots(figsize=(12, 6))
    rects1 = ax.bar(x - width/2, test_accuracies, width, label='Test Accuracy')
    rects2 = ax.bar(x + width/2, cv_means, width, label='CV Mean Accuracy')
    
    ax.set_ylabel('Accuracy')
    ax.set_title('Model Accuracies')
    ax.set_xticks(x)
    ax.set_xticklabels(model_names, rotation=45, ha='right')
    ax.legend()
    
    ax.bar_label(rects1, padding=3, fmt='%.4f')
    ax.bar_label(rects2, padding=3, fmt='%.4f')
    
    # Add error bars for CV
    ax.errorbar(x + width/2, cv_means, yerr=cv_stds, fmt='none', capsize=5, color='black')
    
    fig.tight_layout()
    plt.savefig('model_accuracies.png')
    plt.close()

def plot_confusion_matrices(results, test_generator):
    n_models = len(results)
    fig, axes = plt.subplots(n_models, 1, figsize=(8, 6*n_models))
    if n_models == 1:
        axes = [axes]
    
    for ax, (model_name, result) in zip(axes, results.items()):
        model = keras.models.load_model(f'model_{model_name}_final.h5')
        y_pred = model.predict(test_generator)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_true = test_generator.classes
        
        cm = confusion_matrix(y_true, y_pred_classes)
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
        ax.set_title(f'Confusion Matrix - {model_name}')
        ax.set_xlabel('Predicted')
        ax.set_ylabel('True')
    
    plt.tight_layout()
    plt.savefig('confusion_matrices.png')
    plt.close()

def plot_learning_curves(results):
    fig, axes = plt.subplots(len(results), 2, figsize=(15, 5*len(results)))
    
    for i, (model_name, result) in enumerate(results.items()):
        history = result['history'].history
        
        axes[i, 0].plot(history['accuracy'], label='Train Accuracy')
        axes[i, 0].plot(history['val_accuracy'], label='Validation Accuracy')
        axes[i, 0].set_title(f'{model_name} - Accuracy')
        axes[i, 0].set_xlabel('Epoch')
        axes[i, 0].set_ylabel('Accuracy')
        axes[i, 0].legend()
        
        axes[i, 1].plot(history['loss'], label='Train Loss')
        axes[i, 1].plot(history['val_loss'], label='Validation Loss')
        axes[i, 1].set_title(f'{model_name} - Loss')
        axes[i, 1].set_xlabel('Epoch')
        axes[i, 1].set_ylabel('Loss')
        axes[i, 1].legend()
    
    plt.tight_layout()
    plt.savefig('learning_curves.png')
    plt.close()

def plot_model_comparison(results):
    model_names = list(results.keys())
    test_accuracies = [result['test_accuracy'] for result in results.values()]
    cv_means = [result['cv_mean'] for result in results.values()]
    cv_stds = [result['cv_std'] for result in results.values()]
    
    fig, ax = plt.subplots(figsize=(12, 6))
    x = np.arange(len(model_names))
    
    ax.errorbar(x, cv_means, yerr=cv_stds, fmt='o', label='CV Accuracy', capsize=5)
    ax.scatter(x, test_accuracies, color='red', label='Test Accuracy')
    
    ax.set_xlabel('Model')
    ax.set_ylabel('Accuracy')
    ax.set_title('Model Comparison')
    ax.set_xticks(x)
    ax.set_xticklabels(model_names, rotation=45, ha='right')
    ax.legend()
    
    plt.tight_layout()
    plt.savefig('model_comparison.png')
    plt.close()

def plot_model_architecture(model, model_name):
    # Create a dot graph
    dot = graphviz.Digraph(comment='Model Architecture')
    dot.attr(rankdir='TB', size='8,8')

    # Add nodes for each layer
    for i, layer in enumerate(model.layers):
        # Get layer class name
        layer_type = layer.__class__.__name__
        
        # Get output shape
        if hasattr(layer, 'output_shape'):
            if isinstance(layer.output_shape, tuple):
                shape = str(layer.output_shape)
            elif isinstance(layer.output_shape, list):
                shape = str(layer.output_shape[0])
            else:
                shape = "Unknown"
        else:
            try:
                shape = str(layer.get_output_at(0).shape)
            except:
                shape = "Unknown"
        
        # Create node label
        label = f"{layer_type}\n{shape}"
        
        dot.node(f'layer_{i}', label)
        
        # Add edges
        if i > 0:
            dot.edge(f'layer_{i-1}', f'layer_{i}')

    # Save the graph
    dot.render(f'model_architecture_{model_name}', format='png', cleanup=True)
    print(f"Model architecture saved as model_architecture_{model_name}.png")

    # Also use Keras' built-in plot_model function
    plot_model(model, to_file=f'model_architecture_{model_name}_keras.png', show_shapes=True, show_layer_names=True)
    print(f"Keras model architecture saved as model_architecture_{model_name}_keras.png")

# %%
# Visualize results
plot_training_history(results)
plot_test_accuracy(results)
plot_confusion_matrices(results, test_generator)
plot_learning_curves(results)
plot_model_comparison(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Visualize results
# ----> 2 plot_training_history(results)
#       3 plot_test_accuracy(results)
#       4 plot_confusion_matrices(results, test_generator)
#
# NameError: name 'results' is not defined

# %%
# Print final results
print("\nFinal Results:")
for model_name, result in results.items():
    print(f"{model_name}:")
    print(f"  CV Accuracy: {result['cv_mean']:.4f} (+/- {result['cv_std']:.4f})")
    print(f"  Test Accuracy: {result['test_accuracy']:.4f}")
# Out:
# Final Results:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Print final results
#       2 print("\nFinal Results:")
# ----> 3 for model_name, result in results.items():
#       4     print(f"{model_name}:")
#       5     print(f"  CV Accuracy: {result['cv_mean']:.4f} (+/- {result['cv_std']:.4f})")
#
# NameError: name 'results' is not defined

# %%
# Print current working directory
print(f"Current working directory: {os.getcwd()}")

# Directory where your current models are saved
current_models_dir = '.'  # Assuming they're in the current directory

# Directory to save new format models
save_dir = 'saved_models_keras_format'
os.makedirs(save_dir, exist_ok=True)

# Function to save a model in Keras format
def save_model_keras_format(model, model_name):
    file_path = os.path.join(save_dir, f'{model_name}.keras')
    model.save(file_path)
    print(f"Model saved to {file_path}")

# Model names
model_names = ["Basic CNN", "Advanced CNN", "ResNet50", "VGG16", "MobileNetV2"]

# Number of folds
n_splits = 5

# Process final models and fold models
for model_name in model_names:
    # Process final model
    final_model_filename = f'model_{model_name}_final.h5'
    final_model_filepath = os.path.join(current_models_dir, final_model_filename)
    
    if os.path.exists(final_model_filepath):
        try:
            model = tf.keras.models.load_model(final_model_filepath)
            print(f"Loaded final model: {final_model_filename}")
            save_model_keras_format(model, f"{model_name.replace(' ', '_')}_final")
        except Exception as e:
            print(f"Error processing final model {model_name}: {str(e)}")
    else:
        print(f"Final model file not found: {final_model_filename}")
    
    # Process fold models
    for fold in range(1, n_splits + 1):
        fold_model_filename = f'model_{model_name}_fold_{fold}.h5'
        fold_model_filepath = os.path.join(current_models_dir, fold_model_filename)
        
        if os.path.exists(fold_model_filepath):
            try:
                model = tf.keras.models.load_model(fold_model_filepath)
                print(f"Loaded fold model: {fold_model_filename}")
                save_model_keras_format(model, f"{model_name.replace(' ', '_')}_fold_{fold}")
            except Exception as e:
                print(f"Error processing fold model {model_name} fold {fold}: {str(e)}")
        else:
            print(f"Fold model file not found: {fold_model_filename}")

print("All models processed.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Current working directory: C:\Users\abdul
# Loaded final model: model_Basic CNN_final.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\Basic_CNN_final.keras
# Loaded fold model: model_Basic CNN_fold_1.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\Basic_CNN_fold_1.keras
# Loaded fold model: model_Basic CNN_fold_2.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\Basic_CNN_fold_2.keras
# Loaded fold model: model_Basic CNN_fold_3.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\Basic_CNN_fold_3.keras
# Loaded fold model: model_Basic CNN_fold_4.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\Basic_CNN_fold_4.keras
# Loaded fold model: model_Basic CNN_fold_5.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\Basic_CNN_fold_5.keras
# Loaded final model: model_Advanced CNN_final.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\Advanced_CNN_final.keras
# Loaded fold model: model_Advanced CNN_fold_1.h5
# Model saved to saved_models_keras_format\Advanced_CNN_fold_1.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_Advanced CNN_fold_2.h5
# Model saved to saved_models_keras_format\Advanced_CNN_fold_2.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_Advanced CNN_fold_3.h5
# Model saved to saved_models_keras_format\Advanced_CNN_fold_3.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_Advanced CNN_fold_4.h5
# Model saved to saved_models_keras_format\Advanced_CNN_fold_4.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_Advanced CNN_fold_5.h5
# Model saved to saved_models_keras_format\Advanced_CNN_fold_5.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded final model: model_ResNet50_final.h5
# Model saved to saved_models_keras_format\ResNet50_final.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_ResNet50_fold_1.h5
# Model saved to saved_models_keras_format\ResNet50_fold_1.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_ResNet50_fold_2.h5
# Model saved to saved_models_keras_format\ResNet50_fold_2.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_ResNet50_fold_3.h5
# Model saved to saved_models_keras_format\ResNet50_fold_3.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_ResNet50_fold_4.h5
# Model saved to saved_models_keras_format\ResNet50_fold_4.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_ResNet50_fold_5.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\ResNet50_fold_5.keras
# Loaded final model: model_VGG16_final.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\VGG16_final.keras
# Loaded fold model: model_VGG16_fold_1.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\VGG16_fold_1.keras
# Loaded fold model: model_VGG16_fold_2.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\VGG16_fold_2.keras
# Loaded fold model: model_VGG16_fold_3.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\VGG16_fold_3.keras
# Loaded fold model: model_VGG16_fold_4.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to saved_models_keras_format\VGG16_fold_4.keras
# Loaded fold model: model_VGG16_fold_5.h5
# Model saved to saved_models_keras_format\VGG16_fold_5.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded final model: model_MobileNetV2_final.h5
# Model saved to saved_models_keras_format\MobileNetV2_final.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_MobileNetV2_fold_1.h5
# Model saved to saved_models_keras_format\MobileNetV2_fold_1.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_MobileNetV2_fold_2.h5
# Model saved to saved_models_keras_format\MobileNetV2_fold_2.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_MobileNetV2_fold_3.h5
# Model saved to saved_models_keras_format\MobileNetV2_fold_3.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_MobileNetV2_fold_4.h5
# Model saved to saved_models_keras_format\MobileNetV2_fold_4.keras
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loaded fold model: model_MobileNetV2_fold_5.h5
# Model saved to saved_models_keras_format\MobileNetV2_fold_5.keras
# All models processed.

# %%
print("\nGenerating model architecture diagrams...")
for model_name, result in results.items():
    try:
        model_path = os.path.join(save_dir, f'{model_name.replace(" ", "_")}_final.keras')
        model = keras.models.load_model(model_path)
        
        # Ensure the model is built
        if not model.built:
            dummy_data = np.random.random((1, img_height, img_width, 3))
            model.predict(dummy_data)
        
        plot_model_architecture(model, model_name)
    except Exception as e:
        print(f"Error processing model {model_name}: {str(e)}")
# Out:
# Generating model architecture diagrams...
# Model architecture saved as model_architecture_Basic CNN.png
# Keras model architecture saved as model_architecture_Basic CNN_keras.png
# Model architecture saved as model_architecture_Advanced CNN.png
# Keras model architecture saved as model_architecture_Advanced CNN_keras.png
# Model architecture saved as model_architecture_ResNet50.png
# Keras model architecture saved as model_architecture_ResNet50_keras.png
# Model architecture saved as model_architecture_VGG16.png
# Keras model architecture saved as model_architecture_VGG16_keras.png
# Model architecture saved as model_architecture_MobileNetV2.png
# Keras model architecture saved as model_architecture_MobileNetV2_keras.png
